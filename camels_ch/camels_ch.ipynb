# %% [markdown]
# # Switzerland  瑞士
#
# ![](pictures/Switzerland_relief_location_map_地形图.jpg)

# %% [markdown]
# forcing data: 按站点读，包括径流数据。time_range:["1981-01-01", "2020-12-31"] <br>
# streamflow data:包含在forcing_data里面。

# %% [markdown]
# ### Variables  9个
# - discharge_vol(m3/s),
# - discharge_spec(mm/d),
# - waterlevel(m),
# - precipitation(mm/d),
# - temperature_min(degC),
# - temperature_mean(degC),
# - temperature_max(degC),
# - rel_sun_dur(%),
# - swe(mm)

# %% [markdown]
# 331个流域

# %% [markdown]
# # camelss_ch
# ## annual_timeseries
# CAMELS_CH_annual_data_2004.csv,331个站点，对应331个流域。时间范围，1981年~2020年。<br>
# gauge_id=2004, Land cover attributes as area percentages based on the CORINE land cover databases by the European Copernicus Land Monitoring Service: 1990, 2000, 2006, 2012 and 2018. The years in between were interpolated by linear regression. In 1990, only areas outside Switzerland were covered by clc_1990, therefore only catchments with more then 95% data in clc_1990 were calculated. glaciers source: Swiss Glacier Inventory 1973/2016 and Paul et al, 2020. glacier_mass = glacier_volume*850[kg/m3].<br>
# 18列，17个变量。<br>
# - year
# - crop_perc
# - grass_perc
# - shrub_perc
# - dwood_perc
# - mix_wood_perc
# - ewood_perc
# - wetlands_perc
# - inwater_perc
# - ice_perc
# - loose_rock_perc
# - rock_perc
# - urban_perc
# - blank_perc
# - glac_area_ch(km2)
# - glac_vol_ch(km3)
# - glac_mass_ch(Mt)
# - glac_area_neighbour(km2)
#
# ## catchment_delineations
# 三个shp文件，站点、站点集水区域、整个瑞士区域。
#
# ## glacier_data_original
# ### GI_2003
# 一个shp文件
# ### GI_2015
# 一个shp文件
# ### Glamos_1973
# 一个shp文件
# ### Glamos_2016
# 五个shp文件，一个tif文件。
# ### area_evolution_single.dat
# Glacier areas in km2 between 1980 and 2021 for Swiss glaciers <br>
# SGI-ID 1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
# ### area_evolution_single_gi.dat
# Glacier areas in km2 between 1980 and 2021 for glaciers	in France, Italy and Austria <br>
# GI_03	1980	1981	1982	1983	1984	1985	1986	1987	1988	1989	1990	1991	1992	1993	1994	1995	1996	1997	1998	1999	2000	2001	2002	2003	2004	2005	2006	2007	2008	2009	2010	2011	2012	2013	2014	2015	2016	2017	2018	2019	2020	2021
# ### volume_evolution_single.dat
# Glacier volumes in km3 between 1980 and 2021 for Swiss glaciers <br>
# SGI-ID 1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
#
# ## static_attributes
# ### CAMELS_CH_climate_attributes_obs.csv 气候 331个站点
# Climatic indices calculated with observation-based data (precipitation and temperature) and with simulation-based data (potential evapotranspiration). Only years with complete hydrological year are used (5% missing values are tolerated per hydrological year).<br>
# 15列，12个量<br>
# - gauge_id
# - ind_start_date
# - ind_end_date
# - ind_number_of_years
# - p_mean
# - pet_mean
# - aridity
# - p_seasonality
# - frac_snow
# - high_prec_freq
# - high_prec_dur
# - high_prec_timing
# - low_prec_freq
# - low_prec_dur
# - low_prec_timing
# ### CAMELS_CH_geology_attributes.csv 地质 331个站点
# Geological attributes as rock type percentages based on the global lithology map (GLiMs), and porosity and permeability from the global map of hydrogeological attributes (GLHYMPS 2.0) <br>
# 16列，15个量。<br>
# - gauge_id
# - geo_porosity
# - geo_log10_permeability
# - unconsol_sediments,
# - siliciclastic_sedimentary,
# - mixed_sedimentary,
# - carbonate_sedimentary,
# - pyroclastic,
# - acid_volcanic,
# - basic_volcanic,
# - acid_plutonic,
# - intermediate_plutonic,
# - basic_plutonic,
# - metamorphics,
# - water_geo,
# - ice_geo
#
# ### CAMELS_CH_glacier_attributes.csv 冰川 331个站点
# Glacier attributes about area (km2), volume (km3) and mass (metric mega tons) based on the Swiss glacier inventory (GLAMOS) and the glacier data by Paul et al. (2020) <br>
# 5列，4个变量。<br>
# - gauge_id,
# - glac_area,
# - glac_vol,
# - glac_mass,
# - glac_area_neighbours
#
# ### CAMELS_CH_humaninfluence_attributes.csv 人类影响 331个站点
# Human influence attributes about hydropower and reservoirs derived from data provider resources (BAFU, BFE - Swiss Federal Department of Energy) <br>
# 15列，14个变量。
# - gauge_id,
# - n_inhabitants,
# - dens_inhabitants,
# - hp_count,
# - hp_qturb,
# - hp_inst_turb,
# - hp_max_power,
# - num_reservoir,
# - reservoir_cap,
# - reservoir_he,
# - reservoir_fs,
# - reservoir_irr,
# - reservoir_nousedata,
# - reservoir_year_first,
# - reservoir_year_last
#
# ### CAMELS_CH_hydrogeology_attributes.csv 水文地质 331个站点
# Hydrogeological attributes derived from the hydrogeologic map of Switzerland by Swisstopo <br>
# 11列，10个变量。<br>
# - gauge_id,
# - unconsol_coarse_perc,
# - unconsol_medium_perc,
# - unconsol_fine_perc,
# - unconsol_imperm_perc,
# - hardrock_perc,
# - hardrock_imperm_perc,
# - karst_perc,
# - water_perc,
# - null_perc,
# - ext_area_perc
#
# ### CAMELS_CH_hydrology_attributes_obs.csv 水文 331个站点
# Hydrological signatures calculated with observation-based data. Only years with complete hydrological year are used (5% missing values are tolerated per hydrological year). <br>
# 17列，14个变量。<br>
# - gauge_id,
# - sign_start_date,
# - sign_end_date,
# - sign_number_of_years,
# - q_mean,
# - runoff_ratio,
# - stream_elas,
# - slope_fdc,
# - baseflow_index_landson,
# - hfd_mean,
# - Q5,
# - Q95,
# - high_q_freq,
# - high_q_dur,
# - low_q_freq,
# - low_q_dur,
# - zero_q_freq
#
# ### CAMELS_CH_landcover_attributes.csv 土地覆盖 331个站点
# Land cover attributes as area percentages based on the CORINE land cover database of the year 2000 by the European Copernicus Land Monitoring Service <br>
# 14列，13个变量。<br>
# - gauge_id,
# - crop_perc,
# - grass_perc,
# - scrub_perc,
# - dwood_perc,
# - mixed_wood_perc,
# - ewood_perc,
# - wetlands_perc,
# - inwater_perc,
# - ice_perc,
# - loose_rock_perc,
# - rock_perc,
# - urban_perc,
# - dom_land_cover
#
# ### CAMELS_CH_soil_attributes.csv 土壤 331个站点
# Soil attributes based on EU-SoilHydroGrids (3D soil hydraulic database of Europe) and European Soil Database Derived data (Europe, 1km resolution, soil topological units; ESDD) <br>
# 81列，80个变量。<br>
# - gauge_id,
# - sand_perc,
# - sand_perc_5,
# - sand_perc_25,
# - sand_perc_50,
# - sand_perc_75,
# - sand_perc_90,
# - sand_perc_skewness,
# - sand_perc_missing,
# - silt_perc,
# - silt_perc_5,
# - silt_perc_25,
# - silt_perc_50,
# - silt_perc_75,
# - silt_perc_90,
# - silt_perc_skewness,
# - silt_perc_missing,
# - clay_perc,
# - clay_perc_5,
# - clay_perc_25,
# - clay_perc_50,
# - clay_perc_75,
# - clay_perc_90,
# - clay_perc_skewness,
# - clay_perc_missing,
# - organic_perc,
# - organic_perc_5,
# - organic_perc_25,
# - organic_perc_50,
# - organic_perc_75,
# - organic_perc_90,
# - organic_perc_skewness,
# - organic_perc_missing,
# - bulk_dens,
# - bulk_dens_5,
# - bulk_dens_25,
# - bulk_dens_50,
# - bulk_dens_75,
# - bulk_dens_90,
# - bulk_dens_skewness,
# - bulk_dens_missing,
# - tot_avail_water,
# - tot_avail_water_5,
# - tot_avail_water_25,
# - tot_avail_water_50,
# - tot_avail_water_75,
# - tot_avail_water_90,
# - tot_avail_water_skewness,
# - tot_avail_water_missing,
# - root_depth,
# - root_depth_5,
# - root_depth_25,
# - root_depth_50,
# - root_depth_75,
# - root_depth_90,
# - root_depth_skewness,
# - root_depth_missing,
# - coarse_fragm_perc,
# - coarse_fragm_perc_5,
# - coarse_fragm_perc_25,
# - coarse_fragm_perc_50,
# - coarse_fragm_perc_75,
# - coarse_fragm_perc_90,
# - coarse_fragm_perc_skewness,
# - coarse_fragm_perc_missing,
# - porosity,
# - porosity_5,
# - porosity_25,
# - porosity_50,
# - porosity_75,
# - porosity_90,
# - porosity_skewness,
# - porosity_missing,
# - conductivity,
# - conductivity_5,
# - conductivity_25,
# - conductivity_50,
# - conductivity_75,
# - conductivity_90,
# - conductivity_skewness,
# - conductivity_missing
#
# ### CAMELS_CH_topographic_attributes.csv 地形 331个站点
# Topographic attributes derived from data provider resources (BAFU, Swisstopo, etc.) <br>
# 23列，20个变量 <br>
# - gauge_id
# - country
# - gauge_name
# - water_body_name
# - id6
# - water_body_type
# - gauge_lon
# - gauge_lat
# - gauge_easting
# - gauge_northing
# - gauge_elevation
# - area
# - elev_mean
# - elev_min
# - elev_percentile10
# - elev_percentile25
# - elev_percentile50
# - elev_percentile75
# - elev_percentile90
# - elev_max
# - slope_mean
# - flat_area_perc
# - steep_area_perc
#
# ### simulation_based
# #### CAMELS_CH_climate_attributes_sim.csv 气候 331个站点
# Climatic indices calculated with simulation-based data (precipitation, temperature, and potential evapotranspiration). Only years with complete hydrological year are used (5% missing values are tolerated per hydrological year).<br>
# 15列，12个变量。 <br>
# - gauge_id,
# - ind_start_date,
# - ind_end_date,
# - ind_number_of_years,
# - p_mean,
# - pet_mean,
# - aridity,
# - p_seasonality,
# - frac_snow,
# - high_prec_freq,
# - high_prec_dur,
# - high_prec_timing,
# - low_prec_freq,
# - low_prec_dur,
# - low_prec_timing
#
# #### CAMELS_CH_hydrology_attributes_sim.csv 水文 331个站点
# Hydrological signatures calculated with simulation-based data. Only years with complete hydrological year are used (5% missing values are tolerated per hydrological year). <br>
# 17列，14个变量。
# - gauge_id,
# - sign_start_date,
# - sign_end_date,
# - sign_number_of_years,
# - q_mean,
# - runoff_ratio,
# - stream_elas,
# - slope_fdc,
# - baseflow_index_landson,
# - hfd_mean,
# - Q5,
# - Q95,
# - high_q_freq,
# - high_q_dur,
# - low_q_freq,
# - low_q_dur,
# - zero_q_freq
#
# ### supplements
# #### CAMELS_CH_geology_attributes_supplement.csv 地质 331个站点
# Supplementary geological attributes as rock type percentages based on the map of main lithologies across Switzerland (Swiss Geological Map by Swisstopo) and the map of molasse layers on the Swiss plateau (GeoMol by Swisstopo) <br>
# 22列，20个变量。<br>
# - gauge_id,
# - osm,
# - omm,
# - usm,
# - api,
# - amk,
# - sus,
# - dup,
# - sal,
# - oos,
# - mpk,
# - aap,
# - fju,
# - hes,
# - mps,
# - ups,
# - ops,
# - tie,
# - ukd,
# - uod,
# - ood,
# - qua
#
# #### CAMELS_CH_soil_attributes_supplement.csv 土壤 331个站点
# Supplementary soil attributes based on ISRIC-World Soil Information product SoilGrid (global coverage) <br>
# 65列，64个变量。<br>
# - gauge_id,
# - sg_sand_perc,
# - sg_sand_perc_5,
# - sg_sand_perc_25,
# - sg_sand_perc_50,
# - sg_sand_perc_75,
# - sg_sand_perc_90,
# - sg_sand_perc_skewness,
# - sg_sand_perc_missing,
# - sg_silt_perc,
# - sg_silt_perc_5,
# - sg_silt_perc_25,
# - sg_silt_perc_50,
# - sg_silt_perc_75,
# - sg_silt_perc_90,
# - sg_silt_perc_skewness,
# - sg_silt_perc_missing,
# - sg_clay_perc,
# - sg_clay_perc_5,
# - sg_clay_perc_25,
# - sg_clay_perc_50,
# - sg_clay_perc_75,
# - sg_clay_perc_90,
# - sg_clay_perc_skewness,
# - sg_clay_perc_missing,
# - sg_organic_perc,
# - sg_organic_perc_5,
# - sg_organic_perc_25,
# - sg_organic_perc_50,
# - sg_organic_perc_75,
# - sg_organic_perc_90,
# - sg_organic_perc_skewness,
# - sg_organic_perc_missing,
# - sg_bulk_dens,
# - sg_bulk_dens_5,
# - sg_bulk_dens_25,
# - sg_bulk_dens_50,
# - sg_bulk_dens_75,
# - sg_bulk_dens_90,
# - sg_bulk_dens_skewness,
# - sg_bulk_dens_missing,
# - sg_tot_avail_water,
# - sg_tot_avail_water_5,
# - sg_tot_avail_water_25,
# - sg_tot_avail_water_50,
# - sg_tot_avail_water_75,
# - sg_tot_avail_water_90,
# - sg_tot_avail_water_skewness,
# - sg_tot_avail_water_missing,
# - sg_root_depth,
# - sg_root_depth_5,
# - sg_root_depth_25,
# - sg_root_depth_50,
# - sg_root_depth_75,
# - sg_root_depth_90,
# - sg_root_depth_skewness,
# - sg_root_depth_missing,
# - sg_soil_depth,
# - sg_soil_depth_5,
# - sg_soil_depth_25,
# - sg_soil_depth_50,
# - sg_soil_depth_75,
# - sg_soil_depth_90,
# - sg_soil_depth_skewness,
# - sg_soil_depth_missing
#
# #### CAMELS_CH_topographic_attributes_supplement.csv 地形 331个站点
# Supplementary topographic and location attributes derived from data provider resources (BAFU, Swisstopo, etc.) <br>
# 28列，27个变量。<br>
# - gauge_id,
# - gauge_easting_old,
# - gauge_northing_old,
# - hierarchy_lower,
# - hierarchy_upper,
# - river_basin,
# - river_basin_ch,
# - sub_gauge_id,
# - sub_area,
# - frac_ch,
# - frac_de,
# - frac_at,
# - frac_li,
# - frac_it,
# - frac_fr,
# - ext_r1981,
# - ext_r1992,
# - ext_tabs,
# - ext_srel,
# - ext_sim,
# - perc_jura,
# - perc_black_forest,
# - perc_plateau,
# - perc_alps_north,
# - perc_alps_west,
# - perc_alps_south,
# - perc_alps_east,
# - bio_geo_dominant
#
# ## timeseries
# ### observation_based
# CAMELS_CH_obs_based_2004.csv，331个站点，对应331个流域。时间范围，1981-01-01~2020-12-31，10个变量。<br>
# - date
# - discharge_vol(m3/s)
# - discharge_spec(mm/d)
# - waterlevel(m)
# - precipitation(mm/d)
# - temperature_min(degC)
# - temperature_mean(degC)
# - temperature_max(degC)
# - rel_sun_dur(%)
# - swe(mm)
#
# ### simulation_based
# CAMELS_CH_sim_based_2004.csv，331个站点，对应331个流域。时间范围，1981-01-01~2020-12-31，13个变量。<br>
# - date
# - discharge_vol_sim(m3/s)
# - discharge_spec_sim(mm/d)
# - precipitation_sim(mm/d)
# - temperature_sim(degC)
# - radiation_sim(W/m2)
# - sun_duration_sim(h)
# - wind_sim(m/s)
# - rel_humidity_sim(%)
# - pet_sim(mm/d)
# - et_sim(mm/d)
# - intercept_et_sim(mm/d)
# - intercept_storage_sim(mm)
#
# ## readme.txt
